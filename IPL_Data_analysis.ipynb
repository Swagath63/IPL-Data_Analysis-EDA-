# %% [markdown]
# # IPL Data Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = df = pd.read_csv('C:\\Users\\varad\\Documents\\Data_set\\IPL_Matches_2008_2022.csv')
df.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
df.describe()
# Out:
#                  ID      Margin
# count  9.500000e+02  932.000000
# mean   8.304852e+05   17.056867
# std    3.375678e+05   21.633109
# min    3.359820e+05    1.000000
# 25%    5.012612e+05    6.000000
# 50%    8.297380e+05    8.000000
# 75%    1.175372e+06   19.000000
# max    1.312200e+06  146.000000

# %%
df.shape
# Out:
# (950, 20)

# %%
df.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
T1=df['Team1'].value_counts()

# %%
T2=df['Team2'].value_counts()

# %%
num_matches = pd.concat((T1,T2) , axis=1).sum(axis=1)
num_matches
# Out:
# Royal Challengers Bangalore    226
# Mumbai Indians                 231
# Chennai Super Kings            208
# Kolkata Knight Riders          223
# Kings XI Punjab                190
# Rajasthan Royals               192
# Delhi Daredevils               161
# Sunrisers Hyderabad            152
# Deccan Chargers                 75
# Delhi Capitals                  63
# Pune Warriors                   46
# Punjab Kings                    28
# Gujarat Lions                   30
# Lucknow Super Giants            15
# Gujarat Titans                  16
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Kochi Tuskers Kerala            14
# dtype: int64

# %%
num_matches.plot.bar(figsize = (13,7))
# Out:
# <AxesSubplot:>

# %%
df1.isnull().sum()
# Out:
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
df1['Season'].unique()
# Out:
# array(['2022', '2021', '2020/21', '2019', '2018', '2017', '2016', '2015',
#        '2014', '2013', '2012', '2011', '2009/10', '2009', '2007/08'],
#       dtype=object)

# %%
df1['Season'].value_counts()
# Out:
# 2013       76
# 2022       74
# 2012       74
# 2011       73
# 2021       60
# 2020/21    60
# 2019       60
# 2018       60
# 2016       60
# 2014       60
# 2009/10    60
# 2017       59
# 2015       59
# 2007/08    58
# 2009       57
# Name: Season, dtype: int64

# %%
df1['Player_of_Match'].value_counts().idxmax()
# Out:
# 'AB de Villiers'

# %%
len(df1['Player_of_Match'].unique())
# Out:
# 263

# %%
top_players = df1.groupby('Player_of_Match').size().sort_values(ascending = False)[:10]

top_players.plot.barh()
# Out:
# <AxesSubplot:ylabel='Player_of_Match'>

# %%
df1.groupby('WinningTeam').size().sort_values(ascending=False)
# Out:
# WinningTeam
# Mumbai Indians                 131
# Chennai Super Kings            121
# Kolkata Knight Riders          114
# Royal Challengers Bangalore    109
# Rajasthan Royals                96
# Kings XI Punjab                 88
# Sunrisers Hyderabad             75
# Delhi Daredevils                67
# Delhi Capitals                  36
# Deccan Chargers                 29
# Rising Pune Supergiants         15
# Gujarat Lions                   13
# Punjab Kings                    13
# Gujarat Titans                  12
# Pune Warriors                   12
# Lucknow Super Giants             9
# Kochi Tuskers Kerala             6
# dtype: int64

# %%
tosswins = df1.groupby('TossWinner').size().sort_values(ascending = False)

colors = ['red' , 'green' , 'blue' , 'purple' , 'orange' , 'pink' , 'brown']

plt.figure(figsize = (14,7))

plt.bar(range(len(tosswins)) , tosswins , color = colors)

plt.xticks(range(len(tosswins)) , tosswins.index , rotation = 90)

plt.show()

# %%
df1.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
(df1['MatchNumber'] == 'Final').sum()
# Out:
# 15

# %%
finalWins = df1[df1['MatchNumber'] == 'Final'].WinningTeam.value_counts()
finalWins
# Out:
# Mumbai Indians           5
# Chennai Super Kings      4
# Kolkata Knight Riders    2
# Gujarat Titans           1
# Sunrisers Hyderabad      1
# Deccan Chargers          1
# Rajasthan Royals         1
# Name: WinningTeam, dtype: int64

# %%
values = finalWins.values

# %%
max_finals = finalWins.idxmax()
#print(max_finals)

# %%
max_index = finalWins.index.tolist().index(max_finals)
#print(max_index)

# %%
explode = [0] * len(finalWins.index)
explode[max_index] = 0.1
#print(explode[max_index])
#print(explode)

# %%
plt.pie(values , labels = finalWins.index , 
        explode = explode , shadow=True , autopct = '%1.1f%%')
plt.title('Team with most final wins')
plt.show()

# %%
df2 = pd.read_csv('C:\\Users\\varad\\Documents\\Data_set\\IPL_Ball_by_Ball_2008_2022.csv')

# %%
df2
# Out:
#              ID  innings  overs  ballnumber       batter          bowler  \
# 0       1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1       1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2       1312200        1      0           3   JC Buttler  Mohammed Shami
# 3       1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4       1312200        1      0           5  YBK Jaiswal  Mohammed Shami
# ...         ...      ...    ...         ...          ...             ...
# 225949   335982        2     14           5      P Kumar        I Sharma
# 225950   335982        2     14           6     SB Joshi        I Sharma
# 225951   335982        2     14           7      P Kumar        I Sharma
# 225952   335982        2     15           1     SB Joshi       LR Shukla
# 225953   335982        2     15           2     SB Joshi       LR Shukla
#
#         non-striker extra_type  batsman_run  extras_run  total_run  \
# ...

# %%
df2.describe()
# Out:
#                  ID        innings          overs     ballnumber  \
# count  2.259540e+05  225954.000000  225954.000000  225954.000000
# mean   8.320470e+05       1.483868       9.185679       3.619750
# std    3.379542e+05       0.503104       5.681797       1.810633
# min    3.359820e+05       1.000000       0.000000       1.000000
# 25%    5.012620e+05       1.000000       4.000000       2.000000
# 50%    8.297370e+05       1.000000       9.000000       4.000000
# 75%    1.178395e+06       2.000000      14.000000       5.000000
# max    1.312200e+06       6.000000      19.000000      10.000000
#
#          batsman_run     extras_run     total_run   non_boundary  \
# count  225954.000000  225954.000000  225954.00000  225954.000000
# mean        1.243523       0.066907       1.31043       0.000093
# std         1.618166       0.341470       1.60605       0.009640
# min         0.000000       0.000000       0.00000       0.000000
# ...

# %%
df2.shape
# Out:
# (225954, 17)

# %%
batsmanStats = df2.groupby('batter')['total_run'].sum().sort_values(ascending = False).head(10)
batsmanStats
# Out:
# batter
# V Kohli           6876
# S Dhawan          6561
# DA Warner         6191
# RG Sharma         6083
# SK Raina          5780
# AB de Villiers    5354
# CH Gayle          5336
# RV Uthappa        5246
# MS Dhoni          5221
# KD Karthik        4572
# Name: total_run, dtype: int64

# %%
bowlerStats = df2.groupby('bowler')['isWicketDelivery'].sum().sort_values(ascending = False).head(10)
bowlerStats
# Out:
# bowler
# DJ Bravo           207
# SL Malinga         188
# A Mishra           175
# R Ashwin           174
# YS Chahal          172
# SP Narine          171
# B Kumar            165
# PP Chawla          165
# Harbhajan Singh    161
# JJ Bumrah          161
# Name: isWicketDelivery, dtype: int64

# %%
#Relation between WInning a toss and winning the match
df1.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
(df1['TossWinner'] == df1['WinningTeam']).sum() / len(df1)
# Out:
# 0.5147368421052632

# %%
totaltosswin = df1['TossWinner'].value_counts()
totaltosswin
# Out:
# Mumbai Indians                 123
# Kolkata Knight Riders          114
# Chennai Super Kings            109
# Royal Challengers Bangalore    105
# Rajasthan Royals                99
# Kings XI Punjab                 85
# Delhi Daredevils                80
# Sunrisers Hyderabad             74
# Deccan Chargers                 43
# Delhi Capitals                  36
# Pune Warriors                   20
# Gujarat Lions                   15
# Rising Pune Supergiants         13
# Gujarat Titans                  10
# Punjab Kings                     9
# Kochi Tuskers Kerala             8
# Lucknow Super Giants             7
# Name: TossWinner, dtype: int64

# %%
tossmatchwin = df1[df1['TossWinner'] == df1['WinningTeam']]
totaltossmatchwin = tossmatchwin.WinningTeam.value_counts()
totaltossmatchwin
# Out:
# Mumbai Indians                 70
# Chennai Super Kings            68
# Kolkata Knight Riders          64
# Royal Challengers Bangalore    53
# Rajasthan Royals               49
# Kings XI Punjab                36
# Delhi Daredevils               35
# Sunrisers Hyderabad            34
# Delhi Capitals                 21
# Deccan Chargers                19
# Gujarat Lions                  10
# Rising Pune Supergiants         8
# Gujarat Titans                  7
# Lucknow Super Giants            4
# Punjab Kings                    4
# Kochi Tuskers Kerala            4
# Pune Warriors                   3
# Name: WinningTeam, dtype: int64

# %%
totaltossmatchwin.plot(kind = 'pie' , autopct = '%.2f' , figsize=(15,6))
# Out:
# <AxesSubplot:ylabel='WinningTeam'>

# %%
totaltossmatchwin.head(8).plot(kind = 'pie' , autopct = '%.2f' , figsize=(15,6))
# Out:
# <AxesSubplot:ylabel='WinningTeam'>

# %%
ts = pd.concat((totaltossmatchwin , totaltosswin) , axis = 1)
ts.columns = ['wins' , 'tosswins']
ts
# Out:
#                              wins  tosswins
# Mumbai Indians                 70       123
# Chennai Super Kings            68       109
# Kolkata Knight Riders          64       114
# Royal Challengers Bangalore    53       105
# Rajasthan Royals               49        99
# Kings XI Punjab                36        85
# Delhi Daredevils               35        80
# Sunrisers Hyderabad            34        74
# Delhi Capitals                 21        36
# Deccan Chargers                19        43
# Gujarat Lions                  10        15
# Rising Pune Supergiants         8        13
# Gujarat Titans                  7        10
# Lucknow Super Giants            4         7
# Punjab Kings                    4         9
# Kochi Tuskers Kerala            4         8
# Pune Warriors                   3        20

# %%
percentage = round((ts['wins'] / ts['tosswins'])*100 , 2)
ts['percentage'] = percentage
ts.sort_values('percentage' , ascending = False)
# Out:
#                              wins  tosswins  percentage
# Gujarat Titans                  7        10       70.00
# Gujarat Lions                  10        15       66.67
# Chennai Super Kings            68       109       62.39
# Rising Pune Supergiants         8        13       61.54
# Delhi Capitals                 21        36       58.33
# Lucknow Super Giants            4         7       57.14
# Mumbai Indians                 70       123       56.91
# Kolkata Knight Riders          64       114       56.14
# Royal Challengers Bangalore    53       105       50.48
# Kochi Tuskers Kerala            4         8       50.00
# Rajasthan Royals               49        99       49.49
# Sunrisers Hyderabad            34        74       45.95
# Punjab Kings                    4         9       44.44
# Deccan Chargers                19        43       44.19
# Delhi Daredevils               35        80       43.75
# Kings XI Punjab                36        85       42.35
# ...

# %%
df2.head()
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# ...

# %%
total_runs = df2.groupby('batter')['total_run'].sum()

# %%
df1.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
df1['Margin'].hist()
# Out:
# <AxesSubplot:>

# %%
df2.head()
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# ...

# %%
totalruns = df2.groupby('ID')['total_run'].sum()
totalruns
# Out:
# ID
# 335982     304
# 335983     447
# 335984     261
# 335985     331
# 335986     222
#           ...
# 1304116    317
# 1312197    379
# 1312198    400
# 1312199    318
# 1312200    263
# Name: total_run, Length: 950, dtype: int64

# %%
totalruns.hist()
# Out:
# <AxesSubplot:>

# %%
totalrunsInning = df2.groupby(['ID','innings'])['total_run'].sum()
totalrunsInning
# Out:
# ID       innings
# 335982   1          222
#          2           82
# 335983   1          240
#          2          207
# 335984   1          129
#                    ...
# 1312198  2          193
# 1312199  1          157
#          2          161
# 1312200  1          130
#          2          133
# Name: total_run, Length: 1928, dtype: int64

# %%
totalrunsInning = totalrunsInning.unstack().drop([3,4,5,6] , axis = 1)
totalrunsInning
# Out:
# innings      1      2
# ID
# 335982   222.0   82.0
# 335983   240.0  207.0
# 335984   129.0  132.0
# 335985   165.0  166.0
# 335986   110.0  112.0
# ...        ...    ...
# 1304116  157.0  160.0
# 1312197  188.0  191.0
# 1312198  207.0  193.0
# 1312199  157.0  161.0
# 1312200  130.0  133.0
#
# [950 rows x 2 columns]

# %%
totalrunsInning[1].hist()
# Out:
# <AxesSubplot:>

# %%
totalrunsInning[2].hist()
# Out:
# <AxesSubplot:>
